# %% [markdown]
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>import numpy as np<br />
# import pandas as pd</p>
# <p>pd.set_option("display.precision", 2)</p>
# <p>df = pd.read_csv("scottish_hills.csv") df.head()</p>
# <p>FID SPR22CD SPR22NM BNG_E BNG_N LONG LAT</p>
# </blockquote>
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th>\</th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
# <blockquote>
# <p>0 1 S17000011 Highlands and Islands 244281 863126 -4.61 57.63</p>
# <p>1 2 S17000012 Lothian 316704 666932 -3.33 55.89</p>
# <p>2 3 S17000013 Mid Scotland and Fife 282520 731011 -3.91 56.46</p>
# <p>3 4 S17000014 North East Scotland 352284 799608 -2.79 57.08</p>
# <p>4 5 S17000015 South Scotland 300085 608202 -3.58 55.36</p>
# <p>Shape__Area Shape__Length GlobalID0 4.01e+10 8.79e+06
# 4de001b8-3d33-4844-936b-38af8bfe1ddf1 8.58e+08 1.94e+05
# eba36840-12ec-4932-8cba-f870e418f2892 9.13e+09 6.12e+05
# f3dd5c68-7640-4873-9531-28bd55858dcc3 8.96e+09 5.62e+05
# ddf3c11f-348b-4eeb-a3ce-cd23d9fd17544 1.61e+10 9.47e+05
# 125d605f-8366-4b8f-9b53-f54356f995f4</p>
# <p>print(df.shape)</p>
# <p>(8, 10)</p>
# <p>print(df.columns)</p>
# <p>Index(['FID', 'SPR22CD', 'SPR22NM', 'BNG_E', 'BNG_N', 'LONG',
# 'LAT',</p>
# </blockquote>
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>'Shape__Area', 'Shape__Length', 'GlobalID'],</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>dtype='object')</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></td>
# </tr>
# </tbody>
# </table>
# <blockquote>
# <p>print(df.info())</p>
# <p>&lt;class 'pandas.core.frame.DataFrame'&gt;<br />
# RangeIndex: 8 entries, 0 to 7<br />
# Data columns (total 10 columns):<br />
# # Column Non-Null Count Dtype--- ------ -------------- ----- 0 FID 8
# non-null int64 1 SPR22CD 8 non-null object 2 SPR22NM 8 non-null object 3
# BNG_E 8 non-null int64 4 BNG_N 8 non-null int64 5 LONG 8 non-null
# float64 6 LAT 8 non-null float64</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>7 Shape__Area 8 non-null float64 8 Shape__Length 8 non-null float64 9
# GlobalID 8 non-null objectdtypes: float64(4), int64(3), object(3) memory
# usage: 772.0+ bytes<br />
# None</p>
# <p>df.describe()</p>
# <p>FID BNG_E BNG_N LONG LAT Shape__Area Shape__Length<br />
# count 8.00 8.00 8.00 8.00 8.00 8.00e+008.00e+00<br />
# mean 4.50 285093.00 707314.88 -3.86 56.24 9.83e+091.50e+06<br />
# std 2.45 37723.30 85142.07 0.62 0.76 1.35e+102.96e+06<br />
# min 1.00 239229.00 608202.00 -4.61 55.36 2.08e+088.73e+04<br />
# 25% 2.75 259284.00 662413.00 -4.27 55.83 9.20e+082.25e+05<br />
# 50% 4.50 281938.00 668154.00 -3.90 55.90 5.62e+095.63e+05<br />
# 75% 6.25 304239.75 748160.25 -3.52 56.61 1.09e+106.96e+05<br />
# max 8.00 352284.00 863126.00 -2.79 57.63 4.01e+108.79e+06</p>
# <p>df.describe(include=['object','bool'])</p>
# <p>SPR22CD SPR22NMGlobalID<br />
# count 8 8</p>
# </blockquote>
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th>8</th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th>8</th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></td>
# </tr>
# <tr class="even">
# <td><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th>1</th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></td>
# </tr>
# </tbody>
# </table>
# <blockquote>
# <p>top S17000011 Highlands and Islands
# 4de001b8-3d33-4844-936b-38af8bfe1ddf<br />
# freq 1 1<br />
# unique 8 8</p>
# <p>df['GlobalID'].value_counts()</p>
# <p>GlobalID<br />
# 4de001b8-3d33-4844-936b-38af8bfe1ddf 1
# eba36840-12ec-4932-8cba-f870e418f289 1
# f3dd5c68-7640-4873-9531-28bd55858dcc 1
# ddf3c11f-348b-4eeb-a3ce-cd23d9fd1754 1
# 125d605f-8366-4b8f-9b53-f54356f995f4 1
# 11399a2a-fe6c-469b-91cc-e3b3500c451c 1
# ea7e3847-8701-45de-9579-d05cc522e9c9 1</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>fb0d5d35-83a3-407a-b769-57ec403ac402 1 Name: count, dtype: int64</p>
# <p>df['LAT'].value_counts(normalize=True)</p>
# <p>LAT<br />
# 57.63 0.12<br />
# 55.89 0.12<br />
# 56.46 0.12<br />
# 57.08 0.12<br />
# 55.36 0.12<br />
# 55.77 0.12<br />
# 55.90 0.12<br />
# 55.86 0.12<br />
# Name: proportion, dtype: float64</p>
# <p>df.sort_values(by="LAT", ascending=False).head()</p>
# <p>FID SPR22CD SPR22NM BNG_E BNG_N LONG LAT</p>
# </blockquote>
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th>\</th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
# <blockquote>
# <p>0 1 S17000011 Highlands and Islands 244281 863126 -4.61 57.63</p>
# <p>3 4 S17000014 North East Scotland 352284 799608 -2.79 57.08</p>
# <p>2 3 S17000013 Mid Scotland and Fife 282520 731011 -3.91 56.46</p>
# <p>6 7 S17000019 Central Scotland 281356 669376 -3.90 55.90</p>
# <p>1 2 S17000012 Lothian 316704 666932 -3.33 55.89</p>
# <p>Shape__Area Shape__Length GlobalID0 4.01e+10 8.79e+06
# 4de001b8-3d33-4844-936b-38af8bfe1ddf3 8.96e+09 5.62e+05
# ddf3c11f-348b-4eeb-a3ce-cd23d9fd17542 9.13e+09 6.12e+05
# f3dd5c68-7640-4873-9531-28bd55858dcc6 9.40e+08 2.36e+05
# ea7e3847-8701-45de-9579-d05cc522e9c91 8.58e+08 1.94e+05
# eba36840-12ec-4932-8cba-f870e418f289</p>
# <p>df.sort_values(by=["LAT", "BNG_N"], ascending=[True,
# False]).head()</p>
# <p>FID SPR22CD SPR22NM BNG_E BNG_N LONG LATShape__Area \<br />
# 4 5 S17000015 South Scotland 300085 608202 -3.58 55.361.61e+10<br />
# 5 6 S17000018 West Scotland 239229 655570 -4.56 55.772.29e+09<br />
# 7 8 S17000020 Glasgow 264285 664694 -4.17 55.862.08e+08<br />
# 1 2 S17000012 Lothian 316704 666932 -3.33 55.898.58e+08<br />
# 6 7 S17000019 Central Scotland 281356 669376 -3.90 55.90</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>9.40e+08</p>
# <p>Shape__Length GlobalID4 947497.50
# 125d605f-8366-4b8f-9b53-f54356f995f45 563692.94
# 11399a2a-fe6c-469b-91cc-e3b3500c451c7 87267.24
# fb0d5d35-83a3-407a-b769-57ec403ac4021 193925.75
# eba36840-12ec-4932-8cba-f870e418f2896 235997.35
# ea7e3847-8701-45de-9579-d05cc522e9c9df["LAT"].mean()<br />
# np.float64(56.243035)<br />
# df[df["LAT"]==0.0].mean()</p>
# </blockquote>
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>FID NaN SPR22CD NaN SPR22NM NaN BNG_E NaN BNG_N NaN LONG NaN LAT NaN
# Shape__Area NaN Shape__Length NaN GlobalID NaN dtype: object</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
# <blockquote>
# <p>df[df["LAT"] == 1]["BNG_N"].mean()<br />
# nan<br />
# df[(df["LAT"] == 0) &amp; (df["SPR22NM"] == "No")]["Shape__Area"].max()
# nan<br />
# df.loc[0:3, "SPR22NM":"LONG"]</p>
# </blockquote>
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>SPR22NM BNG_E BNG_N LONG 0 Highlands and Islands 244281 863126 -4.61
# 1 Lothian 316704 666932 -3.33 2 Mid Scotland and Fife 282520 731011
# -3.91 3 North East Scotland 352284 799608 -2.79</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
# <blockquote>
# <p>df.iloc[0:5, 0:3]</p>
# </blockquote>
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>FID SPR22CD SPR22NM 0 1 S17000011 Highlands and Islands 1 2 S17000012
# Lothian 2 3 S17000013 Mid Scotland and Fife 3 4 S17000014 North East
# Scotland 4 5 S17000015 South Scotland</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>df[-1:]</p>
# <p>FID SPR22CD SPR22NM BNG_E BNG_N LONG LAT<br />
# Shape__Area \<br />
# 7 8 S17000020 Glasgow 264285 664694 -4.17 55.86 2.08e+08</p>
# <p>Shape__Length GlobalID7 87267.24
# fb0d5d35-83a3-407a-b769-57ec403ac402</p>
# <p>df.apply(np.max)</p>
# <p>FID 8 SPR22CD S17000020 SPR22NM West Scotland BNG_E 352284 BNG_N
# 863126 LONG -2.79 LAT 57.63 Shape__Area 40126955263.49 Shape__Length
# 8790966.43 GlobalID fb0d5d35-83a3-407a-b769-57ec403ac402 dtype:
# object</p>
# <p>df[df["SPR22NM"].apply(lambda SPR22NM: SPR22NM[00] ==
# "W")].head()</p>
# <p>FID SPR22CD SPR22NM BNG_E BNG_N LONG LATShape__Area \<br />
# 5 6 S17000018 West Scotland 239229 655570 -4.56 55.772.29e+09</p>
# <p>Shape__Length GlobalID5 563692.94
# 11399a2a-fe6c-469b-91cc-e3b3500c451c</p>
# <p>d = {"No": False, "Yes": True}<br />
# df["SPR22NM"] = df["SPR22NM"].map(d)<br />
# df.head()</p>
# </blockquote>
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>FID SPR22CD SPR22NM BNG_E BNG_N LONG LAT Shape__Area \ 0 1 S17000011
# NaN 244281 863126 -4.61 57.63 4.01e+10 1 2 S17000012 NaN 316704 666932
# -3.33 55.89 8.58e+08 2 3 S17000013 NaN 282520 731011 -3.91 56.46
# 9.13e+09 3 4 S17000014 NaN 352284 799608 -2.79 57.08 8.96e+09 4 5
# S17000015 NaN 300085 608202 -3.58 55.36 1.61e+10</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
# <blockquote>
# <p>Shape__Length GlobalID0 8.79e+06
# 4de001b8-3d33-4844-936b-38af8bfe1ddf1 1.94e+05
# eba36840-12ec-4932-8cba-f870e418f2892 6.12e+05
# f3dd5c68-7640-4873-9531-28bd55858dcc3 5.62e+05
# ddf3c11f-348b-4eeb-a3ce-cd23d9fd17544 9.47e+05
# 125d605f-8366-4b8f-9b53-f54356f995f4</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>df.loc[0:5, "SPR22NM":"LONG"]</p>
# </blockquote>
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>SPR22NM BNG_E BNG_N LONG 0 NaN 244281 863126 -4.61 1 NaN 316704
# 666932 -3.33 2 NaN 282520 731011 -3.91 3 NaN 352284 799608 -2.79 4 NaN
# 300085 608202 -3.58 5 NaN 239229 655570 -4.56</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
# <blockquote>
# <p>df.iloc[0:5, 0:3]</p>
# </blockquote>
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>FID SPR22CD SPR22NM 0 1 S17000011 NaN 1 2 S17000012 NaN 2 3 S17000013
# NaN 3 4 S17000014 NaN 4 5 S17000015 NaN</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
# <blockquote>
# <p>df[-1:]</p>
# </blockquote>
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>FID SPR22CD SPR22NM BNG_E BNG_N LONG LAT Shape__Area \ 7 8 S17000020
# NaN 264285 664694 -4.17 55.86 2.08e+08</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
# <blockquote>
# <p>Shape__Length GlobalID7 87267.24
# fb0d5d35-83a3-407a-b769-57ec403ac402</p>
# <p>df.apply(np.max)</p>
# <p>FID 8 SPR22CD S17000020 SPR22NM NaN BNG_E 352284 BNG_N 863126 LONG
# -2.79 LAT 57.63 Shape__Area 40126955263.49 Shape__Length 8790966.43
# GlobalID fb0d5d35-83a3-407a-b769-57ec403ac402 dtype: object</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
